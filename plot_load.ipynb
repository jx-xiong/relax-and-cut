# %%
import json

import numpy as np

import matplotlib.pyplot as plt
import gzip

# %%
file_dir_subhour = "/home/jxxiong/.julia/packages/UnitCommitment/nnguY/instances/matpower_subhour/case1354pegase/2017-01-01.json.gz"
file_dir= "/home/jxxiong/.julia/packages/UnitCommitment/nnguY/instances/matpower/case1354pegase/2017-01-01.json.gz"

# %%
with gzip.open(file_dir_subhour, 'r') as fin:
    data_subhour = json.loads(fin.read().decode('utf-8'))
    
with gzip.open(file_dir, 'r') as fin:
    data = json.loads(fin.read().decode('utf-8'))

# %%
load_subhour = data_subhour['Buses']['b1234']['Load (MW)']
plt.plot(np.arange(len(load_subhour)), load_subhour)

# %%
load = data['Buses']['b3']['Load (MW)']
plt.plot(np.arange(len(load)), load)

# %%
data['Transmission lines']
# Out:
# {'l1': {'Source bus': 'b7351',
#   'Target bus': 'b5441',
#   'Reactance (ohms)': 0.00078,
#   'Susceptance (S)': 2234.73656},
#  'l2': {'Source bus': 'b4314',
#   'Target bus': 'b7571',
#   'Reactance (ohms)': 0.01669,
#   'Susceptance (S)': 104.57335,
#   'Normal flow limit (MW)': 797.0,
#   'Emergency flow limit (MW)': 876.7,
#   'Flow limit penalty ($/MW)': 5000.0},
#  'l3': {'Source bus': 'b5803',
#   'Target bus': 'b3916',
#   'Reactance (ohms)': 0.00432,
#   'Susceptance (S)': 404.0114},
#  'l4': {'Source bus': 'b6757',
#   'Target bus': 'b6036',
#   'Reactance (ohms)': 0.00246,
#   'Susceptance (S)': 709.48344,
#   'Normal flow limit (MW)': 1642.0,
#   'Emergency flow limit (MW)': 1806.2,
#   'Flow limit penalty ($/MW)': 5000.0},
#  'l5': {'Source bus': 'b6757',
#   'Target bus': 'b6921',
#   'Reactance (ohms)': 0.00377,
#   'Susceptance (S)': 462.95206,
#   'Normal flow limit (MW)': 3287.0,
#   'Emergency flow limit (MW)': 3615.7,
#   'Flow limit penalty ($/MW)': 5000.0},
# ...
